# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count - must be at least 500 cities
len(cities)
# Out:
# 739

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print(f"City not found:{city}. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval done!         ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | belushya guba
# City not found:belushya guba. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | sorland
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | sao filipe
# Processing Record 10 of Set 1 | barentsburg
# City not found:barentsburg. Skipping...
# Processing Record 11 of Set 1 | taolanaro
# City not found:taolanaro. Skipping...
# Processing Record 12 of Set 1 | rafaela
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | alofi
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | hihifo
# City not found:hihifo. Skipping...
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | aksha
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | luang prabang
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | saposoa
# Processing Record 26 of Set 1 | oranjemund
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | senanga
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | san cristobal
# Processing Record 34 of Set 1 | manavalakurichi
# Processing Record 35 of Set 1 | baie-saint-paul
# Processing Record 36 of Set 1 | tsihombe
# City not found:tsihombe. Skipping...
# Processing Record 37 of Set 1 | wajir
# Processing Record 38 of Set 1 | mackay
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | huntington
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | menongue
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | kokuy
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found:illoqqortoormiut. Skipping...
# Processing Record 46 of Set 1 | dingle
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | egvekinot
# Processing Record 49 of Set 1 | palmerston
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | harper
# Processing Record 2 of Set 2 | medina del campo
# Processing Record 3 of Set 2 | porto novo
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | yaounde
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | goderich
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | los llanos de aridane
# Processing Record 10 of Set 2 | belaya gora
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | beroroha
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | nelson bay
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | linhares
# Processing Record 18 of Set 2 | jarjis
# City not found:jarjis. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | northam
# Processing Record 21 of Set 2 | namatanai
# Processing Record 22 of Set 2 | caucaia
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | cantaura
# Processing Record 28 of Set 2 | christchurch
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | cordoba
# Processing Record 33 of Set 2 | doha
# Processing Record 34 of Set 2 | tula
# Processing Record 35 of Set 2 | attawapiskat
# City not found:attawapiskat. Skipping...
# Processing Record 36 of Set 2 | taltal
# Processing Record 37 of Set 2 | yining
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | tabiauea
# City not found:tabiauea. Skipping...
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | pecos
# Processing Record 42 of Set 2 | kutum
# Processing Record 43 of Set 2 | camacha
# Processing Record 44 of Set 2 | jumla
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | victoria
# Processing Record 47 of Set 2 | puerto cortes
# City not found:puerto cortes. Skipping...
# Processing Record 48 of Set 2 | yantal
# Processing Record 49 of Set 2 | lagoa
# Processing Record 50 of Set 2 | gambela
# Processing Record 1 of Set 3 | gilgil
# City not found:gilgil. Skipping...
# Processing Record 2 of Set 3 | gua musang
# Processing Record 3 of Set 3 | poso
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | rio gallegos
# Processing Record 7 of Set 3 | sogdiondon
# City not found:sogdiondon. Skipping...
# Processing Record 8 of Set 3 | ossora
# Processing Record 9 of Set 3 | ust-bolsheretsk
# City not found:ust-bolsheretsk. Skipping...
# Processing Record 10 of Set 3 | hondo
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | marystown
# Processing Record 13 of Set 3 | manzhouli
# Processing Record 14 of Set 3 | lazaro cardenas
# Processing Record 15 of Set 3 | dharchula
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | albion
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | bur gabo
# City not found:bur gabo. Skipping...
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | pyshma
# Processing Record 22 of Set 3 | omsukchan
# Processing Record 23 of Set 3 | sayat
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | marechal candido rondon
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | goianira
# Processing Record 31 of Set 3 | beloha
# Processing Record 32 of Set 3 | kloulklubed
# Processing Record 33 of Set 3 | krotoszyn
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | daur
# Processing Record 37 of Set 3 | poum
# Processing Record 38 of Set 3 | khilchipur
# Processing Record 39 of Set 3 | soyo
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | warqla
# City not found:warqla. Skipping...
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | dali
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | comarapa
# Processing Record 46 of Set 3 | thinadhoo
# Processing Record 47 of Set 3 | ayagoz
# Processing Record 48 of Set 3 | hong gai
# Processing Record 49 of Set 3 | saleaula
# City not found:saleaula. Skipping...
# Processing Record 50 of Set 3 | skibbereen
# Processing Record 1 of Set 4 | amderma
# City not found:amderma. Skipping...
# Processing Record 2 of Set 4 | dinsor
# City not found:dinsor. Skipping...
# Processing Record 3 of Set 4 | cap malheureux
# Processing Record 4 of Set 4 | tabat
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | moron
# Processing Record 8 of Set 4 | darhan
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | mount gambier
# Processing Record 11 of Set 4 | tacuarembo
# Processing Record 12 of Set 4 | tselinnoye
# Processing Record 13 of Set 4 | businga
# Processing Record 14 of Set 4 | touros
# Processing Record 15 of Set 4 | mys shmidta
# City not found:mys shmidta. Skipping...
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | bowen
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | faya
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | svetlogorsk
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | bonthe
# Processing Record 28 of Set 4 | rock springs
# Processing Record 29 of Set 4 | dubbo
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | avera
# Processing Record 34 of Set 4 | amapa
# Processing Record 35 of Set 4 | meulaboh
# Processing Record 36 of Set 4 | kampene
# Processing Record 37 of Set 4 | la orilla
# Processing Record 38 of Set 4 | rio grande
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | paso de los toros
# Processing Record 41 of Set 4 | dunedin
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | nicoya
# Processing Record 44 of Set 4 | yuzhno-yeniseyskiy
# City not found:yuzhno-yeniseyskiy. Skipping...
# Processing Record 45 of Set 4 | abu dhabi
# Processing Record 46 of Set 4 | hithadhoo
# Processing Record 47 of Set 4 | puerto carreno
# Processing Record 48 of Set 4 | mazyr
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | bacolod
# Processing Record 1 of Set 5 | camana
# Processing Record 2 of Set 5 | atasu
# Processing Record 3 of Set 5 | vestmannaeyjar
# Processing Record 4 of Set 5 | ponta delgada
# Processing Record 5 of Set 5 | champasak
# Processing Record 6 of Set 5 | nikolskoye
# Processing Record 7 of Set 5 | mayo
# Processing Record 8 of Set 5 | sartell
# Processing Record 9 of Set 5 | kempsey
# Processing Record 10 of Set 5 | roseau
# Processing Record 11 of Set 5 | palmer
# Processing Record 12 of Set 5 | alenquer
# Processing Record 13 of Set 5 | samusu
# City not found:samusu. Skipping...
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | cairns
# Processing Record 16 of Set 5 | tessalit
# Processing Record 17 of Set 5 | gimli
# Processing Record 18 of Set 5 | wagar
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | blagoveshchenka
# Processing Record 21 of Set 5 | stornoway
# Processing Record 22 of Set 5 | balaipungut
# Processing Record 23 of Set 5 | yanan
# City not found:yanan. Skipping...
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | nishihara
# Processing Record 26 of Set 5 | balkhash
# Processing Record 27 of Set 5 | khor
# Processing Record 28 of Set 5 | kirkland lake
# Processing Record 29 of Set 5 | jati
# Processing Record 30 of Set 5 | luba
# Processing Record 31 of Set 5 | mayumba
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | dryden
# Processing Record 34 of Set 5 | kiruna
# Processing Record 35 of Set 5 | olinda
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | kashirskoye
# Processing Record 38 of Set 5 | necocli
# Processing Record 39 of Set 5 | namie
# Processing Record 40 of Set 5 | mar del plata
# Processing Record 41 of Set 5 | oussouye
# Processing Record 42 of Set 5 | tartki
# City not found:tartki. Skipping...
# Processing Record 43 of Set 5 | sivaki
# Processing Record 44 of Set 5 | zatoka
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | yamada
# Processing Record 47 of Set 5 | nhulunbuy
# Processing Record 48 of Set 5 | erenhot
# Processing Record 49 of Set 5 | cayenne
# Processing Record 50 of Set 5 | udachnyy
# Processing Record 1 of Set 6 | braco do norte
# Processing Record 2 of Set 6 | fairbanks
# Processing Record 3 of Set 6 | uzunkopru
# City not found:uzunkopru. Skipping...
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | mutsamudu
# City not found:mutsamudu. Skipping...
# Processing Record 6 of Set 6 | pisco
# Processing Record 7 of Set 6 | salinopolis
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | tupelo
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | ust-nera
# Processing Record 12 of Set 6 | manbij
# Processing Record 13 of Set 6 | manta
# Processing Record 14 of Set 6 | sompeta
# Processing Record 15 of Set 6 | jyvaskyla
# Processing Record 16 of Set 6 | manati
# Processing Record 17 of Set 6 | mandurah
# Processing Record 18 of Set 6 | kirs
# Processing Record 19 of Set 6 | tilichiki
# Processing Record 20 of Set 6 | sambava
# Processing Record 21 of Set 6 | miquelon
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | wanning
# Processing Record 24 of Set 6 | pochutla
# Processing Record 25 of Set 6 | bako
# Processing Record 26 of Set 6 | vanavara
# Processing Record 27 of Set 6 | registro
# Processing Record 28 of Set 6 | prainha
# Processing Record 29 of Set 6 | codrington
# Processing Record 30 of Set 6 | labutta
# City not found:labutta. Skipping...
# Processing Record 31 of Set 6 | atikokan
# Processing Record 32 of Set 6 | hay river
# Processing Record 33 of Set 6 | hasaki
# Processing Record 34 of Set 6 | graham
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | praya
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | qaqortoq
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | lasa
# Processing Record 41 of Set 6 | livingston
# Processing Record 42 of Set 6 | palabuhanratu
# City not found:palabuhanratu. Skipping...
# Processing Record 43 of Set 6 | deep river
# Processing Record 44 of Set 6 | jijiga
# Processing Record 45 of Set 6 | plouzane
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | saldanha
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | arica
# Processing Record 2 of Set 7 | deputatskiy
# Processing Record 3 of Set 7 | nizhniy kuranakh
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | champerico
# Processing Record 6 of Set 7 | brae
# Processing Record 7 of Set 7 | liverpool
# Processing Record 8 of Set 7 | iquique
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | marcona
# City not found:marcona. Skipping...
# Processing Record 12 of Set 7 | albanel
# Processing Record 13 of Set 7 | coari
# Processing Record 14 of Set 7 | pandhana
# Processing Record 15 of Set 7 | sisimiut
# Processing Record 16 of Set 7 | spassk
# Processing Record 17 of Set 7 | bergen
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | naze
# Processing Record 20 of Set 7 | canton
# Processing Record 21 of Set 7 | tirau
# Processing Record 22 of Set 7 | bonavista
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | ola
# Processing Record 25 of Set 7 | batemans bay
# Processing Record 26 of Set 7 | bijar
# Processing Record 27 of Set 7 | martapura
# Processing Record 28 of Set 7 | vila velha
# Processing Record 29 of Set 7 | whitecourt
# Processing Record 30 of Set 7 | ibra
# Processing Record 31 of Set 7 | neustrelitz
# Processing Record 32 of Set 7 | carson city
# Processing Record 33 of Set 7 | manuk mangkaw
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | dujuma
# City not found:dujuma. Skipping...
# Processing Record 37 of Set 7 | elektrogorsk
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | agha jari
# City not found:agha jari. Skipping...
# Processing Record 40 of Set 7 | huilong
# Processing Record 41 of Set 7 | rosa zarate
# Processing Record 42 of Set 7 | bhag
# Processing Record 43 of Set 7 | kudahuvadhoo
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | bull savanna
# Processing Record 46 of Set 7 | umm lajj
# Processing Record 47 of Set 7 | pemangkat
# Processing Record 48 of Set 7 | mahabang parang
# Processing Record 49 of Set 7 | jiddah
# City not found:jiddah. Skipping...
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | hamilton
# Processing Record 2 of Set 8 | ampanihy
# Processing Record 3 of Set 8 | bundaberg
# Processing Record 4 of Set 8 | nuuk
# Processing Record 5 of Set 8 | port hedland
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | diego de almagro
# Processing Record 8 of Set 8 | antalaha
# Processing Record 9 of Set 8 | iqaluit
# Processing Record 10 of Set 8 | suao
# City not found:suao. Skipping...
# Processing Record 11 of Set 8 | gonaives
# Processing Record 12 of Set 8 | mehran
# Processing Record 13 of Set 8 | takoradi
# Processing Record 14 of Set 8 | sabha
# Processing Record 15 of Set 8 | bredy
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | dingzhou
# Processing Record 19 of Set 8 | troitskoye
# Processing Record 20 of Set 8 | mehamn
# Processing Record 21 of Set 8 | baldone
# Processing Record 22 of Set 8 | nizhneyansk
# City not found:nizhneyansk. Skipping...
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | longyearbyen
# Processing Record 25 of Set 8 | mayor pablo lagerenza
# Processing Record 26 of Set 8 | plettenberg bay
# Processing Record 27 of Set 8 | kaeo
# Processing Record 28 of Set 8 | crotone
# Processing Record 29 of Set 8 | coahuayana
# Processing Record 30 of Set 8 | stephenville
# Processing Record 31 of Set 8 | paita
# Processing Record 32 of Set 8 | iralaya
# Processing Record 33 of Set 8 | ahipara
# Processing Record 34 of Set 8 | dafeng
# Processing Record 35 of Set 8 | sao raimundo nonato
# Processing Record 36 of Set 8 | sundsvall
# Processing Record 37 of Set 8 | obigarm
# Processing Record 38 of Set 8 | okato
# Processing Record 39 of Set 8 | tutoia
# Processing Record 40 of Set 8 | yangjiang
# Processing Record 41 of Set 8 | kalutara
# Processing Record 42 of Set 8 | henties bay
# Processing Record 43 of Set 8 | imbituba
# Processing Record 44 of Set 8 | pandan
# Processing Record 45 of Set 8 | gazanjyk
# Processing Record 46 of Set 8 | haibowan
# City not found:haibowan. Skipping...
# Processing Record 47 of Set 8 | butaritari
# Processing Record 48 of Set 8 | praia
# Processing Record 49 of Set 8 | beitbridge
# Processing Record 50 of Set 8 | panzhihua
# Processing Record 1 of Set 9 | huarmey
# Processing Record 2 of Set 9 | oktyabrskoye
# Processing Record 3 of Set 9 | solnechnyy
# Processing Record 4 of Set 9 | rawannawi
# City not found:rawannawi. Skipping...
# Processing Record 5 of Set 9 | grand river south east
# City not found:grand river south east. Skipping...
# Processing Record 6 of Set 9 | paamiut
# Processing Record 7 of Set 9 | karakendzha
# City not found:karakendzha. Skipping...
# Processing Record 8 of Set 9 | dianopolis
# City not found:dianopolis. Skipping...
# Processing Record 9 of Set 9 | andilamena
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | kitwe
# Processing Record 12 of Set 9 | kindu
# Processing Record 13 of Set 9 | eyl
# Processing Record 14 of Set 9 | katobu
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | zeya
# Processing Record 17 of Set 9 | port lincoln
# Processing Record 18 of Set 9 | bilibino
# Processing Record 19 of Set 9 | yermakovskoye
# Processing Record 20 of Set 9 | juneau
# Processing Record 21 of Set 9 | quatre cocos
# Processing Record 22 of Set 9 | mugla
# Processing Record 23 of Set 9 | dwarka
# Processing Record 24 of Set 9 | ballina
# Processing Record 25 of Set 9 | pingyin
# Processing Record 26 of Set 9 | opportunity
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | uyuni
# Processing Record 29 of Set 9 | natal
# Processing Record 30 of Set 9 | gander
# Processing Record 31 of Set 9 | tumannyy
# City not found:tumannyy. Skipping...
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | cururupu
# Processing Record 34 of Set 9 | ahualulco
# Processing Record 35 of Set 9 | cheuskiny
# City not found:cheuskiny. Skipping...
# Processing Record 36 of Set 9 | kamiiso
# Processing Record 37 of Set 9 | omaruru
# Processing Record 38 of Set 9 | rabo de peixe
# Processing Record 39 of Set 9 | korem
# Processing Record 40 of Set 9 | dien bien
# City not found:dien bien. Skipping...
# Processing Record 41 of Set 9 | arinos
# Processing Record 42 of Set 9 | mareeba
# Processing Record 43 of Set 9 | yumen
# Processing Record 44 of Set 9 | kaoma
# Processing Record 45 of Set 9 | talaya
# Processing Record 46 of Set 9 | aras
# Processing Record 47 of Set 9 | beringovskiy
# Processing Record 48 of Set 9 | abalak
# Processing Record 49 of Set 9 | simao
# Processing Record 50 of Set 9 | tongling
# Processing Record 1 of Set 10 | makubetsu
# Processing Record 2 of Set 10 | alta floresta
# Processing Record 3 of Set 10 | byron bay
# Processing Record 4 of Set 10 | forest hills
# Processing Record 5 of Set 10 | dickinson
# Processing Record 6 of Set 10 | caraballeda
# Processing Record 7 of Set 10 | shijak
# Processing Record 8 of Set 10 | floriano
# Processing Record 9 of Set 10 | tinyahuarco
# Processing Record 10 of Set 10 | kalmunai
# Processing Record 11 of Set 10 | negele
# City not found:negele. Skipping...
# Processing Record 12 of Set 10 | jaslo
# Processing Record 13 of Set 10 | hualmay
# Processing Record 14 of Set 10 | ahuimanu
# Processing Record 15 of Set 10 | clarksburg
# Processing Record 16 of Set 10 | kadykchan
# City not found:kadykchan. Skipping...
# Processing Record 17 of Set 10 | teya
# Processing Record 18 of Set 10 | vardo
# Processing Record 19 of Set 10 | chicama
# Processing Record 20 of Set 10 | lavrentiya
# Processing Record 21 of Set 10 | taoudenni
# Processing Record 22 of Set 10 | safakulevo
# Processing Record 23 of Set 10 | tarko-sale
# Processing Record 24 of Set 10 | buchanan
# Processing Record 25 of Set 10 | umm kaddadah
# Processing Record 26 of Set 10 | kumbhraj
# Processing Record 27 of Set 10 | dongsheng
# Processing Record 28 of Set 10 | chupa
# Processing Record 29 of Set 10 | sentyabrskiy
# City not found:sentyabrskiy. Skipping...
# Processing Record 30 of Set 10 | rawson
# Processing Record 31 of Set 10 | ranau
# Processing Record 32 of Set 10 | prado
# Processing Record 33 of Set 10 | raga
# Processing Record 34 of Set 10 | chulym
# Processing Record 35 of Set 10 | fonte boa
# Processing Record 36 of Set 10 | bacuit
# City not found:bacuit. Skipping...
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | waipawa
# Processing Record 39 of Set 10 | mogadishu
# Processing Record 40 of Set 10 | malegaon
# Processing Record 41 of Set 10 | groton
# Processing Record 42 of Set 10 | aykhal
# Processing Record 43 of Set 10 | basco
# Processing Record 44 of Set 10 | salgar
# Processing Record 45 of Set 10 | tyukhtet
# Processing Record 46 of Set 10 | turmalina
# Processing Record 47 of Set 10 | samarskoye
# Processing Record 48 of Set 10 | hoquiam
# Processing Record 49 of Set 10 | ust-omchug
# Processing Record 50 of Set 10 | acajutla
# Processing Record 1 of Set 11 | gazni
# City not found:gazni. Skipping...
# Processing Record 2 of Set 11 | hato mayor
# Processing Record 3 of Set 11 | fallon
# Processing Record 4 of Set 11 | helong
# Processing Record 5 of Set 11 | carutapera
# Processing Record 6 of Set 11 | bandarbeyla
# Processing Record 7 of Set 11 | tateyama
# Processing Record 8 of Set 11 | morondava
# Processing Record 9 of Set 11 | colares
# Processing Record 10 of Set 11 | syracuse
# Processing Record 11 of Set 11 | okhotsk
# Processing Record 12 of Set 11 | khonsa
# Processing Record 13 of Set 11 | atar
# Processing Record 14 of Set 11 | bubaque
# Processing Record 15 of Set 11 | vaitupu
# City not found:vaitupu. Skipping...
# Processing Record 16 of Set 11 | adjumani
# Processing Record 17 of Set 11 | saint-ambroise
# Processing Record 18 of Set 11 | gigmoto
# Processing Record 19 of Set 11 | vangaindrano
# Processing Record 20 of Set 11 | drovyanaya
# Processing Record 21 of Set 11 | muros
# Processing Record 22 of Set 11 | miyang
# Processing Record 23 of Set 11 | islamkot
# Processing Record 24 of Set 11 | nuevo progreso
# Processing Record 25 of Set 11 | yongchang
# Processing Record 26 of Set 11 | salta
# Processing Record 27 of Set 11 | kunming
# Processing Record 28 of Set 11 | luwuk
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | rassvet
# Processing Record 31 of Set 11 | preobrazheniye
# Processing Record 32 of Set 11 | padang
# Processing Record 33 of Set 11 | port blair
# Processing Record 34 of Set 11 | mazagao
# Processing Record 35 of Set 11 | yukon
# Processing Record 36 of Set 11 | charters towers
# Processing Record 37 of Set 11 | jonava
# Processing Record 38 of Set 11 | ayni
# Processing Record 39 of Set 11 | sabang
# Processing Record 40 of Set 11 | hanmer springs
# Processing Record 41 of Set 11 | lucapa
# Processing Record 42 of Set 11 | karlsruhe
# Processing Record 43 of Set 11 | hovd
# Processing Record 44 of Set 11 | manzil salim
# Processing Record 45 of Set 11 | takaka
# Processing Record 46 of Set 11 | constitucion
# Processing Record 47 of Set 11 | molde
# Processing Record 48 of Set 11 | buraydah
# Processing Record 49 of Set 11 | noumea
# Processing Record 50 of Set 11 | tiarei
# Processing Record 1 of Set 12 | caetite
# Processing Record 2 of Set 12 | emba
# Processing Record 3 of Set 12 | gwadar
# Processing Record 4 of Set 12 | seguin
# Processing Record 5 of Set 12 | urumqi
# Processing Record 6 of Set 12 | njombe
# Processing Record 7 of Set 12 | hearst
# Processing Record 8 of Set 12 | asyut
# Processing Record 9 of Set 12 | hunza
# City not found:hunza. Skipping...
# Processing Record 10 of Set 12 | winslow
# Processing Record 11 of Set 12 | puerto escondido
# Processing Record 12 of Set 12 | pak phanang
# Processing Record 13 of Set 12 | seregno
# Processing Record 14 of Set 12 | santa isabel do rio negro
# Processing Record 15 of Set 12 | sioux lookout
# Processing Record 16 of Set 12 | alcacer do sal
# Processing Record 17 of Set 12 | pontianak
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | coihaique
# Processing Record 20 of Set 12 | hirara
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | saint-joseph
# Processing Record 23 of Set 12 | hualahuises
# Processing Record 24 of Set 12 | port keats
# Processing Record 25 of Set 12 | emerald
# Processing Record 26 of Set 12 | alegrete
# Processing Record 27 of Set 12 | sai buri
# Processing Record 28 of Set 12 | san gabriel
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | tezu
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | antioquia
# Processing Record 33 of Set 12 | anadyr
# Processing Record 34 of Set 12 | mahadday weyne
# City not found:mahadday weyne. Skipping...
# Processing Record 35 of Set 12 | athens
# Processing Record 36 of Set 12 | ishigaki
# Processing Record 37 of Set 12 | dzhebariki-khaya
# Processing Record 38 of Set 12 | qurbus
# Processing Record 39 of Set 12 | half moon bay
# Processing Record 40 of Set 12 | kamaishi
# Processing Record 41 of Set 12 | dicabisagan
# Processing Record 42 of Set 12 | turukhansk
# Processing Record 43 of Set 12 | naftah
# City not found:naftah. Skipping...
# Processing Record 44 of Set 12 | kangundo
# Processing Record 45 of Set 12 | sandpoint
# Processing Record 46 of Set 12 | north platte
# Processing Record 47 of Set 12 | mocuba
# Processing Record 48 of Set 12 | maniitsoq
# Processing Record 49 of Set 12 | ginir
# Processing Record 50 of Set 12 | rigaud
# Processing Record 1 of Set 13 | nsanje
# Processing Record 2 of Set 13 | eldikan
# City not found:eldikan. Skipping...
# Processing Record 3 of Set 13 | tarudant
# City not found:tarudant. Skipping...
# Processing Record 4 of Set 13 | ilhabela
# Processing Record 5 of Set 13 | pacifica
# Processing Record 6 of Set 13 | birao
# Processing Record 7 of Set 13 | kiama
# Processing Record 8 of Set 13 | cassilandia
# Processing Record 9 of Set 13 | portel
# Processing Record 10 of Set 13 | marsa matruh
# Processing Record 11 of Set 13 | prince rupert
# Processing Record 12 of Set 13 | irbeyskoye
# Processing Record 13 of Set 13 | guerrero negro
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | verkhnetulomskiy
# Processing Record 16 of Set 13 | inirida
# Processing Record 17 of Set 13 | talara
# Processing Record 18 of Set 13 | russell
# Processing Record 19 of Set 13 | hanyang
# Processing Record 20 of Set 13 | maykor
# Processing Record 21 of Set 13 | nawa
# Processing Record 22 of Set 13 | pundaguitan
# Processing Record 23 of Set 13 | umzimvubu
# City not found:umzimvubu. Skipping...
# Processing Record 24 of Set 13 | saint-augustin
# Processing Record 25 of Set 13 | biryusinsk
# Processing Record 26 of Set 13 | aden
# Processing Record 27 of Set 13 | lolua
# City not found:lolua. Skipping...
# Processing Record 28 of Set 13 | biak
# Processing Record 29 of Set 13 | lata
# Processing Record 30 of Set 13 | yelizovo
# Processing Record 31 of Set 13 | haines junction
# Processing Record 32 of Set 13 | dolbeau
# City not found:dolbeau. Skipping...
# Processing Record 33 of Set 13 | anzhero-sudzhensk
# Processing Record 34 of Set 13 | xiuyan
# Processing Record 35 of Set 13 | igarka
# Processing Record 36 of Set 13 | baindur
# Processing Record 37 of Set 13 | havoysund
# Processing Record 38 of Set 13 | akdepe
# Processing Record 39 of Set 13 | grand gaube
# Processing Record 40 of Set 13 | manvi
# Processing Record 41 of Set 13 | conakry
# Processing Record 42 of Set 13 | axim
# Processing Record 43 of Set 13 | nivala
# Processing Record 44 of Set 13 | ganzhou
# Processing Record 45 of Set 13 | lishui
# Processing Record 46 of Set 13 | idaho falls
# Processing Record 47 of Set 13 | maragogi
# Processing Record 48 of Set 13 | ajdabiya
# Processing Record 49 of Set 13 | port-gentil
# Processing Record 50 of Set 13 | merauke
# Processing Record 1 of Set 14 | ashtabula
# Processing Record 2 of Set 14 | san carlos de bariloche
# Processing Record 3 of Set 14 | bathsheba
# Processing Record 4 of Set 14 | tautira
# Processing Record 5 of Set 14 | paradwip
# City not found:paradwip. Skipping...
# Processing Record 6 of Set 14 | satitoa
# City not found:satitoa. Skipping...
# Processing Record 7 of Set 14 | goure
# Processing Record 8 of Set 14 | nabire
# Processing Record 9 of Set 14 | jiuquan
# Processing Record 10 of Set 14 | barawe
# City not found:barawe. Skipping...
# Processing Record 11 of Set 14 | karasburg
# Processing Record 12 of Set 14 | denpasar
# Processing Record 13 of Set 14 | san juan del sur
# Processing Record 14 of Set 14 | nakhon thai
# Processing Record 15 of Set 14 | verkh-suetka
# Processing Record 16 of Set 14 | mudgee
# Processing Record 17 of Set 14 | oranjestad
# Processing Record 18 of Set 14 | kalnibolotskaya
# Processing Record 19 of Set 14 | san policarpo
# Processing Record 20 of Set 14 | kathmandu
# Processing Record 21 of Set 14 | brookhaven
# Processing Record 22 of Set 14 | kenai
# Processing Record 23 of Set 14 | nemuro
# Processing Record 24 of Set 14 | vila franca do campo
# Processing Record 25 of Set 14 | tindwari
# Processing Record 26 of Set 14 | labuhan
# Processing Record 27 of Set 14 | sayyan
# Processing Record 28 of Set 14 | mouzakion
# City not found:mouzakion. Skipping...
# Processing Record 29 of Set 14 | prachuap khiri khan
# Processing Record 30 of Set 14 | nizwa
# Processing Record 31 of Set 14 | meyungs
# City not found:meyungs. Skipping...
# Processing Record 32 of Set 14 | jiroft
# City not found:jiroft. Skipping...
# Processing Record 33 of Set 14 | aksu
# Processing Record 34 of Set 14 | morehead
# Processing Record 35 of Set 14 | papetoai
# Processing Record 36 of Set 14 | severobaykalsk
# Processing Record 37 of Set 14 | sorvag
# City not found:sorvag. Skipping...
# Processing Record 38 of Set 14 | jalu
# Processing Record 39 of Set 14 | praia da vitoria
# Processing Record 40 of Set 14 | bad munstereifel
# Processing Record 41 of Set 14 | collie
# Processing Record 42 of Set 14 | kahului
# Processing Record 43 of Set 14 | moree
# Processing Record 44 of Set 14 | progreso
# Processing Record 45 of Set 14 | luyang
# Processing Record 46 of Set 14 | ryotsu
# Processing Record 47 of Set 14 | newton
# Processing Record 48 of Set 14 | pudozh
# Processing Record 49 of Set 14 | hit
# Processing Record 50 of Set 14 | kazalinsk
# City not found:kazalinsk. Skipping...
# Processing Record 1 of Set 15 | pergamino
# Processing Record 2 of Set 15 | tambacounda
# Processing Record 3 of Set 15 | sao borja
# Processing Record 4 of Set 15 | kambove
# Processing Record 5 of Set 15 | rovaniemi
# Processing Record 6 of Set 15 | nyurba
# Processing Record 7 of Set 15 | williams lake
# Processing Record 8 of Set 15 | santa catarina de tepehuanes
# Processing Record 9 of Set 15 | mortka
# Processing Record 10 of Set 15 | anton lizardo
# Processing Record 11 of Set 15 | nurlat
# Processing Record 12 of Set 15 | lianzhou
# Processing Record 13 of Set 15 | makat
# Processing Record 14 of Set 15 | sol-iletsk
# Processing Record 15 of Set 15 | patea
# Processing Record 16 of Set 15 | camamu
# Processing Record 17 of Set 15 | saeby
# Processing Record 18 of Set 15 | alto vera
# City not found:alto vera. Skipping...
# Processing Record 19 of Set 15 | belmonte
# Processing Record 20 of Set 15 | wageningen
# Processing Record 21 of Set 15 | woodward
# Processing Record 22 of Set 15 | mapimi
# Processing Record 23 of Set 15 | manggar
# Processing Record 24 of Set 15 | ritchie
# Processing Record 25 of Set 15 | flinders
# Processing Record 26 of Set 15 | karaul
# City not found:karaul. Skipping...
# Processing Record 27 of Set 15 | rio grande city
# Processing Record 28 of Set 15 | san carlos
# Processing Record 29 of Set 15 | juba
# Processing Record 30 of Set 15 | la rioja
# Processing Record 31 of Set 15 | garissa
# Processing Record 32 of Set 15 | kavaratti
# Processing Record 33 of Set 15 | aksehir
# Processing Record 34 of Set 15 | seoul
# Processing Record 35 of Set 15 | tshikapa
# Processing Record 36 of Set 15 | dawson creek
# Processing Record 37 of Set 15 | ulladulla
# Processing Record 38 of Set 15 | matara
# Processing Record 39 of Set 15 | port macquarie
# -----------------------------
# Data Retrieval done!
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Rikitea      PF -23.1203 -134.9692     77.99        85
# 1              Hilo      US  19.7297 -155.0900     81.28        93
# 2            Albany      US  42.6001  -73.9662     55.81        62
# 3         Upernavik      GL  72.7868  -56.1549      2.55        94
# 4           Mataura      NZ -46.1927  168.8643     64.24        61
# ..              ...     ...      ...       ...       ...       ...
# 669        Tshikapa      CD  -6.4167   20.8000     69.71        82
# 670    Dawson Creek      CA  55.7666 -120.2362     53.24        50
# 671       Ulladulla      AU -35.3500  150.4667     63.50        36
# 672          Matara      LK   5.9485   80.5353     82.18        80
# 673  Port Macquarie      AU -31.4333  152.9167     65.89        61
#
#      Cloudiness  Wind Speed Current Description
# 0            80       16.42          light rain
# 1           100        6.91          light rain
# 2           100        4.74     overcast clouds
# 3            58        4.90       broken clouds
# 4           100        2.30     overcast clouds
# ..          ...         ...                 ...
# 669          83        2.35       broken clouds
# 670          20        5.75          few clouds
# 671           0        9.98           clear sky
# 672          99       13.42     overcast clouds
# 673          94       10.58          light rain
#
# [674 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
